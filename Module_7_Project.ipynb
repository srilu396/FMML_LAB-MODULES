# %% [markdown]
# <a href="https://colab.research.google.com/github/srilu396/FMML_LAB-MODULES/blob/main/Module_7_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Module 7 Project: Movie Recommendation Engine

# %% [markdown]
# `Module Coordinator: Ganesh Chandan`

# %% [markdown]
# In this module, we will try to create a Movie Recommendation System using different unsupervised learning techniques.

# %%
# dataset download

# !wget https://files.grouplens.org/datasets/movielens/ml-100k.zip
# !wget https://files.grouplens.org/datasets/movielens/ml-latest-small.zip
# !unzip ml-latest-small.zip
# Out:
# --2024-03-07 16:29:00--  https://files.grouplens.org/datasets/movielens/ml-latest-small.zip
# Resolving files.grouplens.org (files.grouplens.org)... 128.101.65.152
# Connecting to files.grouplens.org (files.grouplens.org)|128.101.65.152|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 978202 (955K) [application/zip]
# Saving to: ‘ml-latest-small.zip’
#
# ml-latest-small.zip 100%[===================>] 955.28K  2.67MB/s    in 0.3s
#
# 2024-03-07 16:29:00 (2.67 MB/s) - ‘ml-latest-small.zip’ saved [978202/978202]
#
# Archive:  ml-latest-small.zip
#    creating: ml-latest-small/
#   inflating: ml-latest-small/links.csv
#   inflating: ml-latest-small/tags.csv
#   inflating: ml-latest-small/ratings.csv
#   inflating: ml-latest-small/README.txt
#   inflating: ml-latest-small/movies.csv

# %% [markdown]
# ## Clustering based recommendation

# %%
# Import Libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.sparse import csr_matrix
from mpl_toolkits.axes_grid1 import make_axes_locatable
from sklearn.cluster import KMeans
from sklearn.metrics import mean_squared_error
import itertools
from sklearn.metrics import silhouette_samples, silhouette_score

# %%
# Import the Movies dataset
movies = pd.read_csv('ml-latest-small/movies.csv')
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
# Import the ratings dataset
ratings = pd.read_csv('ml-latest-small/ratings.csv')
ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
# Print the number of records and the total number of movies
print('The dataset contains: ', len(ratings), ' ratings of ', len(movies), ' movies.')
# Out:
# The dataset contains:  100836  ratings of  9742  movies.

# %% [markdown]
# ### Romance versus Science Fiction
#
# We will start by considering a subset of users and discovering what are their favourite genre. We will do this by defining a function that will calculate each user’s average rating for all science fiction and romance movies.

# %%
# Function to get the genre ratings
def get_genre_ratings(ratings, movies, genres, column_names):
    genre_ratings = pd.DataFrame()
    for genre in genres:
        genre_movies = movies[movies['genres'].str.contains(genre) ]
        avg_genre_votes_per_user = ratings[ratings['movieId'].isin(genre_movies['movieId'])].loc[:, ['userId', 'rating']].groupby(['userId'])['rating'].mean().round(2)

        genre_ratings = pd.concat([genre_ratings, avg_genre_votes_per_user], axis=1)

    genre_ratings.columns = column_names
    return genre_ratings# Calculate the average rating of romance and scifi movies
genre_ratings = get_genre_ratings(ratings, movies, ['Romance', 'Sci-Fi'], ['avg_romance_rating', 'avg_scifi_rating'])
genre_ratings.head()
# Out:
#    avg_romance_rating  avg_scifi_rating
# 1                4.31              4.22
# 2                4.50              3.88
# 3                0.50              4.20
# 4                3.38              2.83
# 5                3.09              2.50

# %% [markdown]
# In order to have a more delimited subset of people to study, we are going to bias our grouping to only get ratings from those users that like either romance or science fiction movies.

# %%
# Function to get the biased dataset
def bias_genre_rating_dataset(genre_ratings, score_limit_1, score_limit_2):
    biased_dataset =    genre_ratings[((genre_ratings['avg_romance_rating'] < score_limit_1 - 0.2) & (genre_ratings['avg_scifi_rating'] > score_limit_2)) | ((genre_ratings['avg_scifi_rating'] < score_limit_1) & (genre_ratings['avg_romance_rating'] > score_limit_2))]
    biased_dataset = pd.concat([biased_dataset[:300], genre_ratings[:2]])
    biased_dataset = pd.DataFrame(biased_dataset.to_records())
    return biased_dataset

# Bias the dataset
biased_dataset = bias_genre_rating_dataset(genre_ratings, 3.2, 2.5)

# Printing the resulting number of records & the head of the dataset
print( "Number of records: ", len(biased_dataset))
biased_dataset.head()
# Out:
# Number of records:  162
#    index  avg_romance_rating  avg_scifi_rating
# 0      3                0.50              4.20
# 1      4                3.38              2.83
# 2      5                3.09              2.50
# 3      7                2.65              3.15
# 4      9                3.17              3.00

# %%
# Defining the scatterplot drawing function
def draw_scatterplot(x_data, x_label, y_data, y_label):
    fig = plt.figure(figsize=(8,8))
    ax = fig.add_subplot(111)
    plt.xlim(0, 5)
    plt.ylim(0, 5)
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)
    ax.scatter(x_data, y_data, s=30)

# Plot the scatterplot
draw_scatterplot(biased_dataset['avg_scifi_rating'],'Avg scifi rating', biased_dataset['avg_romance_rating'], 'Avg romance rating')

# %%
# Let's turn our dataset into a list
X = biased_dataset[['avg_scifi_rating','avg_romance_rating']].values

# Import KMeans
from sklearn.cluster import KMeans

# Create an instance of KMeans to find two clusters
kmeans_1 = KMeans(n_clusters=2)

# Use fit_predict to cluster the dataset
predictions = kmeans_1.fit_predict(X)

# Defining the cluster plotting function
def draw_clusters(biased_dataset, predictions, cmap='viridis'):
    fig = plt.figure(figsize=(8,8))
    ax = fig.add_subplot(111)
    plt.xlim(0, 5)
    plt.ylim(0, 5)
    ax.set_xlabel('Avg scifi rating')
    ax.set_ylabel('Avg romance rating')
    clustered = pd.concat([biased_dataset.reset_index(), pd.DataFrame({'group':predictions})], axis=1)
    plt.scatter(clustered['avg_scifi_rating'], clustered['avg_romance_rating'], c=clustered['group'], s=20, cmap=cmap)

# Plot
draw_clusters(biased_dataset, predictions)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# Create an instance of KMeans to find three clusters
kmeans_2 = KMeans(n_clusters=3)
# Use fit_predict to cluster the dataset
predictions_2 = kmeans_2.fit_predict(X)
# Plot
draw_clusters(biased_dataset, predictions_2)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# It is evident now that the science-fiction rating has started to come into play:
#
#     People who like sci-fi and romance modeately belong to the green group.
#     People who like scifi but not romance belong to the yello group.
#     People who like romance but not sci-fi belong to the purple group.

# %% [markdown]
# Finding optimal clusters using silhouette score

# %%
# Selecting our dataset to study
df = biased_dataset[['avg_scifi_rating','avg_romance_rating']]

# Choose the range of k values to test.
# We added a stride of 5 to improve performance. We don't need to calculate the error for every k value
possible_k_values = range(2, len(X)+1, 5)

# Define function to calculate the clustering errors
def clustering_errors(k, data):
    kmeans = KMeans(n_clusters=k).fit(data)
    predictions = kmeans.predict(data)
    #cluster_centers = kmeans.cluster_centers_
    # errors = [mean_squared_error(row, cluster_centers[cluster]) for row, cluster in zip(data.values, predictions)]
    # return sum(errors)
    silhouette_avg = silhouette_score(data, predictions)
    return silhouette_avg

# Calculate error values for all k values we're interested in
errors_per_k = [clustering_errors(k, X) for k in possible_k_values]

# Plot the each value of K vs. the silhouette score at that value
fig, ax = plt.subplots(figsize=(16, 6))
plt.plot(possible_k_values, errors_per_k)

# Ticks and grid
xticks = np.arange(min(possible_k_values), max(possible_k_values)+1, 5.0)
ax.set_xticks(xticks, minor=False)
ax.set_xticks(xticks, minor=True)
ax.xaxis.grid(True, which='both')
yticks = np.arange(round(min(errors_per_k), 2), max(errors_per_k), .05)
ax.set_yticks(yticks, minor=False)
ax.set_yticks(yticks, minor=True)
ax.yaxis.grid(True, which='both')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# <ipython-input-11-ea56d5ac5a15>:10: ConvergenceWarning: Number of distinct clusters (157) found smaller than n_clusters (162). Possibly due to duplicate points in X.
#   kmeans = KMeans(n_clusters=k).fit(data)

# %% [markdown]
# We will chose the K = 7 as it is the one that yields the best score and will be easier to visualize.

# %%
# Create an instance of KMeans to find seven clusters
kmeans_4 = KMeans(n_clusters=7)
# Use fit_predict to cluster the dataset
predictions_4 = kmeans_4.fit_predict(X)
# Plot
draw_clusters(biased_dataset, predictions_4, cmap='Accent')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# Up to now, we have only analyzed romance and science-fiction movies. Let us see what happens when adding other genre to our analysis by adding Action movies.

# %%
# Select our biased dataset and add action genre
biased_dataset_3_genres = get_genre_ratings(ratings, movies, ['Romance','Sci-Fi', 'Action'],
['avg_romance_rating', 'avg_scifi_rating', 'avg_action_rating'])
# Drop null values
biased_dataset_3_genres = bias_genre_rating_dataset(biased_dataset_3_genres, 3.2, 2.5).dropna()
# Print the number of records and the head of our dataset
print( "Number of records: ", len(biased_dataset_3_genres))
biased_dataset_3_genres.head()
# Out:
# Number of records:  161
#    index  avg_romance_rating  avg_scifi_rating  avg_action_rating
# 0      3                0.50              4.20               3.57
# 1      4                3.38              2.83               3.32
# 2      5                3.09              2.50               3.11
# 3      7                2.65              3.15               3.26
# 4      9                3.17              3.00               3.12

# %%
# Turn dataset into a list
X_with_action = biased_dataset_3_genres[['avg_scifi_rating','avg_romance_rating','avg_action_rating']].values# Create an instance of KMeans to find seven clusters
kmeans_5 = KMeans(n_clusters=7)
# Use fit_predict to cluster the dataset
predictions_5 = kmeans_5.fit_predict(X_with_action)
# Define 3d plotting function
def draw_clusters_3d(biased_dataset_3, predictions):
    fig = plt.figure(figsize=(8,8))
    ax = fig.add_subplot(111)
    plt.xlim(0, 5)
    plt.ylim(0, 5)
    ax.set_xlabel('Avg scifi rating')
    ax.set_ylabel('Avg romance rating')
    clustered = pd.concat([biased_dataset_3.reset_index(), pd.DataFrame({'group':predictions})], axis=1)
    colors = itertools.cycle(plt.rcParams["axes.prop_cycle"].by_key()["color"])
    for g in clustered.group.unique():
        color = next(colors)
        for index, point in clustered[clustered.group == g].iterrows():
            if point['avg_action_rating'].astype(float) > 3:
                size = 50
            else:
                size = 15
            plt.scatter(point['avg_scifi_rating'],
                        point['avg_romance_rating'],
                        s=size,
                        color=color)# Plot
draw_clusters_3d(biased_dataset_3_genres, predictions_5)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# The size of the dots represent the ratings of the action movies.

# %% [markdown]
# # Exercise 1
#
# ## Instead of choosing a n_clusters as 7, play around with different k
# ## Find the optimal no of clusters with 3 genre_ratings data we just created using silhouette score method

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.impute import SimpleImputer

imputer=SimpleImputer(strategy='mean')

genre_ratings_imputed=imputer.fit_transform(genre_ratings)

silhouette_scores=[]

for k in range(2,11):
    kmeans=KMeans(n_clusters=k, random_state=42)
    kmeans.fit(genre_ratings_imputed)
    silhouette_avg=silhouette_score(genre_ratings_imputed, kmeans.labels_)
    silhouette_scores.append((k, silhouette_avg))

best_k, best_silhouette_score=max(silhouette_scores, key=lambda x: x[1])

print(f"The optimal number of clusters is: {best_k} with a silhouette score of {best_silhouette_score}")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# The optimal number of clusters is: 2 with a silhouette score of 0.402772563719914

# %% [markdown]
# ### Taking users into consideration

# %% [markdown]
# Once we have seen and understood how the K-Means algorithm group the users by their movie genre preferences, we are going to take a bigger picture of the dataset and explore how users rate individual movies.
#
# To do so, we will subset the dataset by ‘userid’ vs ‘user rating’ as follows.

# %%
# Merge the two tables then pivot so we have Users X Movies dataframe
ratings_title = pd.merge(ratings, movies[['movieId', 'title']], on='movieId' )
user_movie_ratings = pd.pivot_table(ratings_title, index='userId', columns= 'title', values='rating')

# Print he number of dimensions and a subset of the dataset
print('dataset dimensions: ', user_movie_ratings.shape, '\n\nSubset example:')
user_movie_ratings.iloc[:6, :10]
# Out:
# dataset dimensions:  (610, 9719)
#
# Subset example:
# title   '71 (2014)  'Hellboy': The Seeds of Creation (2004)  \
# userId
# 1              NaN                                      NaN
# 2              NaN                                      NaN
# 3              NaN                                      NaN
# 4              NaN                                      NaN
# 5              NaN                                      NaN
# 6              NaN                                      NaN
#
# title   'Round Midnight (1986)  'Salem's Lot (2004)  \
# userId
# 1                          NaN                  NaN
# 2                          NaN                  NaN
# 3                          NaN                  NaN
# 4                          NaN                  NaN
# 5                          NaN                  NaN
# 6                          NaN                  NaN
#
# title   'Til There Was You (1997)  'Tis the Season for Love (2015)  \
# userId
# 1                             NaN                              NaN
# 2                             NaN                              NaN
# 3                             NaN                              NaN
# 4                             NaN                              NaN
# 5                             NaN                              NaN
# 6                             NaN                              NaN
#
# title   'burbs, The (1989)  'night Mother (1986)  (500) Days of Summer (2009)  \
# userId
# 1                      NaN                   NaN                          NaN
# 2                      NaN                   NaN                          NaN
# 3                      NaN                   NaN                          NaN
# 4                      NaN                   NaN                          NaN
# 5                      NaN                   NaN                          NaN
# 6                      NaN                   NaN                          NaN
#
# title   *batteries not included (1987)
# userId
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# 5                                  NaN
# 6                                  NaN

# %%
# Define Function to get the most rated movies
def get_most_rated_movies(user_movie_ratings, max_number_of_movies):
    # 1- Count
    user_movie_ratings = user_movie_ratings.append(user_movie_ratings.count(), ignore_index=True)
    # 2- sort
    user_movie_ratings_sorted = user_movie_ratings.sort_values(len(user_movie_ratings)-1, axis=1, ascending=False)
    user_movie_ratings_sorted = user_movie_ratings_sorted.drop(user_movie_ratings_sorted.tail(1).index)
    # 3- slice
    most_rated_movies = user_movie_ratings_sorted.iloc[:, :max_number_of_movies]
    return most_rated_movies

# Define function to get the user who rate a movie the most
def get_users_who_rate_the_most(most_rated_movies, n_users):
    most_rated_movies['num_ratings'] = - most_rated_movies.isnull().sum(axis=1)
    most_rated_movies = most_rated_movies.sort_values(by=['num_ratings'], ascending=False)
    most_rated_movies = most_rated_movies.iloc[:n_users, :]
    most_rated_movies = most_rated_movies.drop('num_ratings', axis=1)
    return most_rated_movies

# Define the sorting by rating function
def sort_by_rating_density(user_movie_ratings, n_movies, n_users):
    most_rated_movies = get_most_rated_movies(user_movie_ratings, n_movies)
    most_rated_movies = get_users_who_rate_the_most(most_rated_movies, n_users)
    return most_rated_movies

# choose the number of movies and users and sort
n_movies = 30
n_users = 18
most_rated_movies_users_selection = sort_by_rating_density(user_movie_ratings, n_movies, n_users)

# Print the result
# print(most_rated_movies_users_selection)
print('dataset dimensions: ', most_rated_movies_users_selection.shape)
print(most_rated_movies_users_selection.head())
# Out:
# dataset dimensions:  (18, 30)
# title  Forrest Gump (1994)  Shawshank Redemption, The (1994)  \
# 479                    5.0                               5.0
# 473                    3.0                               5.0
# 67                     3.5                               3.0
# 413                    5.0                               5.0
# 589                    5.0                               4.5
#
# title  Pulp Fiction (1994)  Silence of the Lambs, The (1991)  \
# 479                    4.0                               4.5
# 473                    4.0                               4.5
# 67                     2.0                               3.5
# 413                    5.0                               4.0
# 589                    4.5                               3.5
#
# title  Matrix, The (1999)  Star Wars: Episode IV - A New Hope (1977)  \
# 479                   5.0                                        4.5
# 473                   4.5                                        4.0
# 67                    4.5                                        5.0
# 413                   5.0                                        5.0
# 589                   4.0                                        5.0
#
# title  Jurassic Park (1993)  Braveheart (1995)  \
# 479                     5.0                5.0
# 473                     4.5                3.0
# 67                      3.5                2.5
# 413                     4.0                5.0
# 589                     4.0                4.0
#
# title  Terminator 2: Judgment Day (1991)  Schindler's List (1993)  ...  \
# 479                                  4.5                      5.0  ...
# 473                                  4.0                      5.0  ...
# 67                                   3.5                      4.0  ...
# 413                                  5.0                      4.0  ...
# 589                                  4.5                      5.0  ...
#
# title  Star Wars: Episode VI - Return of the Jedi (1983)  \
# 479                                                  3.5
# 473                                                  4.0
# 67                                                   5.0
# 413                                                  5.0
# 589                                                  4.5
#
# title  Godfather, The (1972)  Fugitive, The (1993)  Batman (1989)  \
# 479                      5.0                   3.5            4.5
# 473                      5.0                   5.0            4.0
# 67                       4.0                   4.5            4.0
# 413                      5.0                   5.0            4.0
# 589                      5.0                   4.0            3.5
#
# title  Saving Private Ryan (1998)  \
# 479                           4.5
# 473                           3.0
# 67                            4.0
# 413                           5.0
# 589                           4.0
#
# title  Lord of the Rings: The Two Towers, The (2002)  \
# 479                                              4.5
# 473                                              5.0
# 67                                               4.0
# 413                                              5.0
# 589                                              5.0
#
# title  Lord of the Rings: The Return of the King, The (2003)  Aladdin (1992)  \
# 479                                                  4.0                 4.0
# 473                                                  5.0                 4.0
# 67                                                   4.5                 3.5
# 413                                                  4.0                 4.0
# 589                                                  4.5                 4.0
#
# title  Fargo (1996)  Sixth Sense, The (1999)
# 479             4.0                      4.0
# 473             4.0                      5.0
# 67              2.5                      2.5
# 413             5.0                      3.0
# 589             4.0                      3.5
#
# [5 rows x 30 columns]
# <ipython-input-17-0b2c7ceec495>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   user_movie_ratings = user_movie_ratings.append(user_movie_ratings.count(), ignore_index=True)

# %%
# Define the plotting heatmap function
def draw_movies_heatmap(most_rated_movies_users_selection, axis_labels=True):

    fig = plt.figure(figsize=(15,4))
    ax = plt.gca()

    # Draw heatmap
    heatmap = ax.imshow(most_rated_movies_users_selection,  interpolation='nearest', vmin=0, vmax=5, aspect='auto')
    if axis_labels:
        ax.set_yticks(np.arange(most_rated_movies_users_selection.shape[0]) , minor=False)
        ax.set_xticks(np.arange(most_rated_movies_users_selection.shape[1]) , minor=False)
        ax.invert_yaxis()
        ax.xaxis.tick_top()
        labels = most_rated_movies_users_selection.columns.str[:40]
        ax.set_xticklabels(labels, minor=False)
        ax.set_yticklabels(most_rated_movies_users_selection.index, minor=False)
        plt.setp(ax.get_xticklabels(), rotation=90)
    else:
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

    ax.grid(False)
    ax.set_ylabel('User id')# Separate heatmap from color bar
    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.05)# Color bar
    cbar = fig.colorbar(heatmap, ticks=[5, 4, 3, 2, 1, 0], cax=cax)
    cbar.ax.set_yticklabels(['5 stars', '4 stars','3 stars','2 stars','1 stars','0 stars'])
    plt.show()# Print the heatmap
draw_movies_heatmap(most_rated_movies_users_selection)

# %%
# Pivot the dataset and choose the first 1000 movies
user_movie_ratings =  pd.pivot_table(ratings_title, index='userId', columns= 'title', values='rating')
most_rated_movies_1k = get_most_rated_movies(user_movie_ratings, 1000).replace(np.nan, 0)
# Out:
# <ipython-input-17-0b2c7ceec495>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   user_movie_ratings = user_movie_ratings.append(user_movie_ratings.count(), ignore_index=True)

# %%
from scipy import sparse

# Conversion to sparse csr matrix
sparse_ratings = sparse.csr_matrix(most_rated_movies_1k.values)

# %% [markdown]
# ### Large Scale Clustering

# %%
# 20 clusters
predictions = KMeans(n_clusters=20, algorithm='full').fit_predict(sparse_ratings)
# Select the mas number of users and movies heatmap cluster
# Cluster and print some of them
clustered = pd.concat([get_most_rated_movies(user_movie_ratings, 1000).reset_index(), pd.DataFrame({'group':predictions})], axis=1)
# draw_movie_clusters(clustered, max_users, max_movies)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1366: FutureWarning: algorithm='full' is deprecated, it will be removed in 1.3. Using 'lloyd' instead.
#   warnings.warn(
# <ipython-input-17-0b2c7ceec495>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   user_movie_ratings = user_movie_ratings.append(user_movie_ratings.count(), ignore_index=True)

# %% [markdown]
# ### Predictions and Recommendation

# %%
# Pick a cluster ID from the clusters above
cluster_number = 11
# Let's filter to only see the region of the dataset with the most number of values
n_users = 75
n_movies = 300
cluster = clustered[clustered.group == cluster_number].drop(['index', 'group'], axis=1)
print(cluster)
# Sort and print the cluster
cluster = sort_by_rating_density(cluster, n_movies, n_users)
draw_movies_heatmap(cluster, axis_labels=False)
# Out:
#      Forrest Gump (1994)  Shawshank Redemption, The (1994)  \
# 5                    5.0                               5.0
# 37                   3.0                               5.0
# 39                   NaN                               5.0
# 42                   5.0                               4.0
# 57                   4.0                               5.0
# 108                  5.0                               5.0
# 116                  4.0                               5.0
# 135                  NaN                               NaN
# 173                  3.0                               NaN
# 180                  5.0                               NaN
# 228                  4.0                               5.0
# 234                  5.0                               4.0
# 239                  5.0                               3.0
# 272                  NaN                               NaN
# 283                  5.0                               4.0
# 313                  4.0                               5.0
# 352                  NaN                               5.0
# 372                  4.0                               5.0
# 403                  4.0                               4.0
# 410                  5.0                               4.0
# 435                  4.0                               4.0
# 445                  3.0                               NaN
# 446                  4.0                               5.0
# 454                  5.0                               5.0
# 457                  5.0                               NaN
# 469                  5.0                               4.0
# 475                  5.0                               5.0
# 540                  5.0                               4.0
# 558                  4.0                               5.0
# 565                  5.0                               5.0
# 583                  5.0                               NaN
# 591                  5.0                               4.0
# 593                  NaN                               NaN
# 601                  3.0                               5.0
# 603                  NaN                               NaN
#
#      Pulp Fiction (1994)  Silence of the Lambs, The (1991)  \
# 5                    2.0                               4.0
# 37                   3.0                               3.0
# 39                   5.0                               NaN
# 42                   3.0                               NaN
# 57                   5.0                               NaN
# 108                  5.0                               4.0
# 116                  4.0                               5.0
# 135                  1.0                               3.0
# 173                  3.0                               NaN
# 180                  2.0                               3.0
# 228                  5.0                               4.0
# 234                  4.0                               5.0
# 239                  2.0                               NaN
# 272                  4.0                               5.0
# 283                  4.0                               NaN
# 313                  1.0                               3.0
# 352                  5.0                               5.0
# 372                  5.0                               5.0
# 403                  3.0                               4.0
# 410                  5.0                               5.0
# 435                  NaN                               3.0
# 445                  4.0                               5.0
# 446                  5.0                               4.0
# 454                  NaN                               5.0
# 457                  4.0                               NaN
# 469                  3.0                               NaN
# 475                  3.0                               NaN
# 540                  NaN                               4.0
# 558                  3.0                               NaN
# 565                  4.0                               NaN
# 583                  3.0                               4.0
# 591                  4.0                               5.0
# 593                  NaN                               5.0
# 601                  5.0                               5.0
# 603                  5.0                               5.0
#
#      Matrix, The (1999)  Star Wars: Episode IV - A New Hope (1977)  \
# 5                   NaN                                        NaN
# 37                  NaN                                        NaN
# 39                  NaN                                        NaN
# 42                  NaN                                        NaN
# 57                  NaN                                        NaN
# 108                 NaN                                        NaN
# 116                 NaN                                        NaN
# 135                 NaN                                        NaN
# 173                 NaN                                        NaN
# 180                 NaN                                        NaN
# 228                 NaN                                        NaN
# 234                 NaN                                        NaN
# 239                 NaN                                        NaN
# 272                 NaN                                        NaN
# 283                 NaN                                        NaN
# 313                 NaN                                        5.0
# 352                 NaN                                        NaN
# 372                 NaN                                        NaN
# 403                 NaN                                        NaN
# 410                 NaN                                        NaN
# 435                 NaN                                        NaN
# 445                 NaN                                        NaN
# 446                 NaN                                        NaN
# 454                 NaN                                        NaN
# 457                 NaN                                        NaN
# 469                 NaN                                        NaN
# 475                 NaN                                        NaN
# 540                 NaN                                        NaN
# 558                 NaN                                        5.0
# 565                 NaN                                        NaN
# 583                 NaN                                        NaN
# 591                 NaN                                        NaN
# 593                 5.0                                        NaN
# 601                 NaN                                        5.0
# 603                 NaN                                        NaN
#
#      Jurassic Park (1993)  Braveheart (1995)  \
# 5                     5.0                5.0
# 37                    3.0                5.0
# 39                    NaN                4.0
# 42                    4.0                3.0
# 57                    4.0                5.0
# 108                   3.0                5.0
# 116                   4.0                5.0
# 135                   NaN                5.0
# 173                   5.0                NaN
# 180                   5.0                3.0
# 228                   3.0                5.0
# 234                   4.0                4.0
# 239                   4.0                5.0
# 272                   4.0                NaN
# 283                   5.0                5.0
# 313                   3.0                4.0
# 352                   NaN                3.0
# 372                   4.0                4.0
# 403                   4.0                4.0
# 410                   5.0                4.0
# 435                   3.0                NaN
# 445                   4.0                NaN
# 446                   4.0                5.0
# 454                   3.0                4.0
# 457                   5.0                5.0
# 469                   5.0                5.0
# 475                   4.0                NaN
# 540                   5.0                5.0
# 558                   5.0                4.0
# 565                   4.0                5.0
# 583                   5.0                5.0
# 591                   5.0                5.0
# 593                   5.0                5.0
# 601                   4.0                5.0
# 603                   NaN                3.0
#
#      Terminator 2: Judgment Day (1991)  Schindler's List (1993)  ...  \
# 5                                  3.0                      3.0  ...
# 37                                 NaN                      5.0  ...
# 39                                 NaN                      NaN  ...
# 42                                 5.0                      NaN  ...
# 57                                 4.0                      5.0  ...
# 108                                3.0                      3.0  ...
# 116                                4.0                      5.0  ...
# 135                                NaN                      NaN  ...
# 173                                4.0                      3.0  ...
# 180                                NaN                      NaN  ...
# 228                                5.0                      4.0  ...
# 234                                4.0                      5.0  ...
# 239                                4.0                      NaN  ...
# 272                                5.0                      NaN  ...
# 283                                5.0                      NaN  ...
# 313                                5.0                      5.0  ...
# 352                                NaN                      NaN  ...
# 372                                3.0                      5.0  ...
# 403                                NaN                      4.0  ...
# 410                                3.0                      5.0  ...
# 435                                4.0                      5.0  ...
# 445                                5.0                      5.0  ...
# 446                                4.0                      NaN  ...
# 454                                3.0                      5.0  ...
# 457                                3.0                      NaN  ...
# 469                                5.0                      5.0  ...
# 475                                5.0                      NaN  ...
# 540                                3.0                      NaN  ...
# 558                                4.0                      NaN  ...
# 565                                NaN                      5.0  ...
# 583                                5.0                      NaN  ...
# 591                                5.0                      NaN  ...
# 593                                5.0                      NaN  ...
# 601                                5.0                      5.0  ...
# 603                                NaN                      NaN  ...
#
#      Pay It Forward (2000)  Buffy the Vampire Slayer (1992)  Arrival (2016)  \
# 5                      NaN                              NaN             NaN
# 37                     NaN                              NaN             NaN
# 39                     NaN                              NaN             NaN
# 42                     NaN                              NaN             NaN
# 57                     NaN                              NaN             NaN
# 108                    NaN                              NaN             NaN
# 116                    NaN                              NaN             NaN
# 135                    NaN                              NaN             NaN
# 173                    NaN                              NaN             NaN
# 180                    NaN                              NaN             NaN
# 228                    NaN                              NaN             NaN
# 234                    NaN                              NaN             NaN
# 239                    NaN                              NaN             NaN
# 272                    NaN                              NaN             NaN
# 283                    NaN                              NaN             NaN
# 313                    NaN                              NaN             NaN
# 352                    NaN                              NaN             NaN
# 372                    NaN                              NaN             NaN
# 403                    NaN                              NaN             NaN
# 410                    NaN                              NaN             NaN
# 435                    NaN                              NaN             NaN
# 445                    NaN                              NaN             NaN
# 446                    NaN                              NaN             NaN
# 454                    NaN                              NaN             NaN
# 457                    NaN                              NaN             NaN
# 469                    NaN                              NaN             NaN
# 475                    NaN                              NaN             NaN
# 540                    NaN                              NaN             NaN
# 558                    NaN                              NaN             NaN
# 565                    NaN                              NaN             NaN
# 583                    NaN                              NaN             NaN
# 591                    NaN                              NaN             NaN
# 593                    NaN                              NaN             NaN
# 601                    NaN                              NaN             NaN
# 603                    NaN                              NaN             NaN
#
#      The Hunger Games: Catching Fire (2013)  Scary Movie 2 (2001)  \
# 5                                       NaN                   NaN
# 37                                      NaN                   NaN
# 39                                      NaN                   NaN
# 42                                      NaN                   NaN
# 57                                      NaN                   NaN
# 108                                     NaN                   NaN
# 116                                     NaN                   NaN
# 135                                     NaN                   NaN
# 173                                     NaN                   NaN
# 180                                     NaN                   NaN
# 228                                     NaN                   NaN
# 234                                     NaN                   NaN
# 239                                     NaN                   NaN
# 272                                     NaN                   NaN
# 283                                     NaN                   NaN
# 313                                     NaN                   NaN
# 352                                     NaN                   NaN
# 372                                     NaN                   NaN
# 403                                     NaN                   NaN
# 410                                     NaN                   NaN
# 435                                     NaN                   NaN
# 445                                     NaN                   NaN
# 446                                     NaN                   NaN
# 454                                     NaN                   NaN
# 457                                     NaN                   NaN
# 469                                     NaN                   NaN
# 475                                     NaN                   NaN
# 540                                     NaN                   NaN
# 558                                     NaN                   NaN
# 565                                     NaN                   NaN
# 583                                     NaN                   NaN
# 591                                     NaN                   NaN
# 593                                     NaN                   NaN
# 601                                     NaN                   NaN
# 603                                     NaN                   NaN
#
#      Virgin Suicides, The (1999)  National Lampoon's Vacation (1983)  \
# 5                            NaN                                 NaN
# 37                           NaN                                 NaN
# 39                           NaN                                 NaN
# 42                           NaN                                 NaN
# 57                           NaN                                 NaN
# 108                          NaN                                 NaN
# 116                          NaN                                 NaN
# 135                          NaN                                 NaN
# 173                          NaN                                 NaN
# 180                          NaN                                 NaN
# 228                          NaN                                 NaN
# 234                          NaN                                 NaN
# 239                          NaN                                 NaN
# 272                          NaN                                 NaN
# 283                          NaN                                 NaN
# 313                          NaN                                 NaN
# 352                          NaN                                 NaN
# 372                          NaN                                 NaN
# 403                          NaN                                 NaN
# 410                          NaN                                 NaN
# 435                          NaN                                 NaN
# 445                          NaN                                 NaN
# 446                          NaN                                 NaN
# 454                          NaN                                 NaN
# 457                          NaN                                 NaN
# 469                          NaN                                 NaN
# 475                          NaN                                 NaN
# 540                          NaN                                 NaN
# 558                          NaN                                 NaN
# 565                          NaN                                 NaN
# 583                          NaN                                 NaN
# 591                          NaN                                 NaN
# 593                          NaN                                 NaN
# 601                          NaN                                 NaN
# 603                          NaN                                 NaN
#
#      Muppet Treasure Island (1996)  Last Emperor, The (1987)  Bad Santa (2003)
# 5                              NaN                       NaN               NaN
# 37                             NaN                       NaN               NaN
# 39                             4.0                       NaN               NaN
# 42                             5.0                       NaN               NaN
# 57                             NaN                       NaN               NaN
# 108                            NaN                       NaN               NaN
# 116                            NaN                       NaN               NaN
# 135                            NaN                       NaN               NaN
# 173                            NaN                       NaN               NaN
# 180                            NaN                       NaN               NaN
# 228                            NaN                       NaN               NaN
# 234                            NaN                       NaN               NaN
# 239                            NaN                       NaN               NaN
# 272                            NaN                       NaN               NaN
# 283                            NaN                       NaN               NaN
# 313                            3.0                       NaN               NaN
# 352                            NaN                       NaN               NaN
# 372                            NaN                       NaN               NaN
# 403                            NaN                       NaN               NaN
# 410                            NaN                       NaN               NaN
# 435                            NaN                       NaN               NaN
# 445                            NaN                       NaN               NaN
# 446                            NaN                       NaN               NaN
# 454                            NaN                       NaN               NaN
# 457                            NaN                       NaN               NaN
# 469                            NaN                       NaN               NaN
# 475                            NaN                       NaN               NaN
# 540                            NaN                       NaN               NaN
# 558                            3.0                       NaN               NaN
# 565                            NaN                       NaN               NaN
# 583                            NaN                       NaN               NaN
# 591                            NaN                       NaN               NaN
# 593                            NaN                       NaN               NaN
# 601                            NaN                       NaN               NaN
# 603                            NaN                       NaN               NaN
#
# [35 rows x 1000 columns]
# <ipython-input-17-0b2c7ceec495>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   user_movie_ratings = user_movie_ratings.append(user_movie_ratings.count(), ignore_index=True)

# %%
# Fill in the name of the column/movie. e.g. 'Forrest Gump (1994)'
movie_name = "Matrix, The (1999)"
cluster[movie_name].mean()
# Out:
# 5.0

# %%
# The average rating of 20 movies as rated by the users in the cluster
cluster.mean().head(20)
# Out:
# Batman (1989)                        3.485294
# Fugitive, The (1993)                 4.250000
# True Lies (1994)                     3.378788
# Lion King, The (1994)                4.062500
# Mask, The (1994)                     3.375000
# Jurassic Park (1993)                 4.193548
# Aladdin (1992)                       3.887097
# Die Hard: With a Vengeance (1995)    3.629032
# Pulp Fiction (1994)                  3.677419
# Dances with Wolves (1990)            3.741935
# Firm, The (1993)                     3.700000
# Braveheart (1995)                    4.466667
# Apollo 13 (1995)                     3.850000
# Sleepless in Seattle (1993)          3.896552
# Forrest Gump (1994)                  4.413793
# Star Trek: Generations (1994)        3.344828
# Clear and Present Danger (1994)      3.689655
# Ace Ventura: Pet Detective (1994)    2.896552
# Speed (1994)                         3.775862
# Beauty and the Beast (1991)          3.964286
# dtype: float64

# %%
cluster
# Out:
#     Batman (1989)  Fugitive, The (1993)  True Lies (1994)  \
# 0             3.0                   5.0               4.0
# 6             3.0                   4.0               4.0
# 32            4.5                   4.5               4.5
# 28            3.0                   3.0               3.0
# 15            3.0                   3.0               2.0
# 33            4.0                   5.0               3.0
# 4             3.0                   5.0               3.0
# 19            3.0                   4.0               4.0
# 12            3.0                   3.0               3.0
# 5             4.0                   4.0               3.0
# 17            3.0                   3.0               NaN
# 21            3.0                   3.0               2.0
# 3             5.0                   5.0               3.0
# 7             4.0                   5.0               3.0
# 31            5.0                   5.0               5.0
# 9             2.0                   4.0               2.0
# 16            4.0                   5.0               3.0
# 30            3.0                   4.0               5.0
# 14            5.0                   4.0               4.0
# 2             4.0                   3.0               3.0
# 1             4.0                   5.0               3.0
# 34            4.0                   NaN               3.0
# 25            3.0                   4.0               5.0
# 29            3.0                   4.0               3.0
# 20            3.0                   5.0               3.0
# 8             5.0                   5.0               3.0
# 22            3.0                   4.0               4.0
# 27            3.0                   5.0               4.0
# 11            3.0                   4.0               4.0
# 10            3.0                   5.0               4.0
# 18            NaN                   4.0               3.0
# 23            3.0                   4.0               3.0
# 26            4.0                   5.0               3.0
# 24            3.0                   5.0               3.0
# 13            3.0                   4.0               NaN
#
#     Lion King, The (1994)  Mask, The (1994)  Jurassic Park (1993)  \
# 0                     5.0               4.0                   5.0
# 6                     4.0               3.0                   4.0
# 32                    5.0               4.0                   5.0
# 28                    4.0               3.0                   5.0
# 15                    4.0               3.0                   3.0
# 33                    4.0               5.0                   4.0
# 4                     4.0               4.0                   4.0
# 19                    4.0               2.0                   5.0
# 12                    4.0               4.0                   4.0
# 5                     3.0               3.0                   3.0
# 17                    5.0               1.0                   4.0
# 21                    3.0               3.0                   4.0
# 3                     5.0               5.0                   4.0
# 7                     5.0               4.0                   NaN
# 31                    5.0               4.0                   5.0
# 9                     NaN               3.0                   5.0
# 16                    4.0               3.0                   NaN
# 30                    5.0               3.0                   5.0
# 14                    NaN               5.0                   5.0
# 2                     5.0               4.0                   NaN
# 1                     2.0               2.0                   3.0
# 34                    4.0               3.0                   NaN
# 25                    4.0               4.0                   5.0
# 29                    2.0               4.0                   4.0
# 20                    4.0               3.0                   3.0
# 8                     NaN               NaN                   5.0
# 22                    4.0               4.0                   4.0
# 27                    3.0               2.0                   5.0
# 11                    5.0               NaN                   4.0
# 10                    4.0               3.0                   3.0
# 18                    3.0               3.0                   4.0
# 23                    3.0               3.0                   3.0
# 26                    4.0               NaN                   4.0
# 24                    5.0               3.0                   5.0
# 13                    5.0               4.0                   4.0
#
#     Aladdin (1992)  Die Hard: With a Vengeance (1995)  Pulp Fiction (1994)  \
# 0              5.0                                3.0                  2.0
# 6              4.0                                3.0                  4.0
# 32             4.5                                4.5                  NaN
# 28             4.0                                3.0                  3.0
# 15             3.0                                2.0                  1.0
# 33             NaN                                5.0                  5.0
# 4              5.0                                4.0                  5.0
# 19             NaN                                3.0                  5.0
# 12             4.0                                5.0                  2.0
# 5              3.0                                3.0                  5.0
# 17             NaN                                NaN                  5.0
# 21             3.0                                3.0                  4.0
# 3              5.0                                5.0                  3.0
# 7              3.0                                5.0                  1.0
# 31             5.0                                3.0                  4.0
# 9              4.0                                3.0                  2.0
# 16             3.0                                5.0                  5.0
# 30             4.0                                5.0                  3.0
# 14             5.0                                5.0                  4.0
# 2              4.0                                4.0                  5.0
# 1              3.0                                NaN                  3.0
# 34             3.0                                4.0                  5.0
# 25             3.0                                3.0                  3.0
# 29             3.0                                3.0                  4.0
# 20             3.0                                3.0                  NaN
# 8              4.0                                3.0                  3.0
# 22             5.0                                4.0                  5.0
# 27             3.0                                3.0                  NaN
# 11             4.0                                NaN                  4.0
# 10             NaN                                3.0                  5.0
# 18             4.0                                3.0                  3.0
# 23             3.0                                3.0                  NaN
# 26             5.0                                3.0                  3.0
# 24             4.0                                4.0                  4.0
# 13             5.0                                NaN                  4.0
#
#     Dances with Wolves (1990)  ...  Mission: Impossible III (2006)  \
# 0                         5.0  ...                             NaN
# 6                         4.0  ...                             NaN
# 32                        NaN  ...                             NaN
# 28                        NaN  ...                             NaN
# 15                        2.0  ...                             NaN
# 33                        3.0  ...                             NaN
# 4                         3.0  ...                             NaN
# 19                        5.0  ...                             NaN
# 12                        4.0  ...                             NaN
# 5                         3.0  ...                             NaN
# 17                        4.0  ...                             NaN
# 21                        4.0  ...                             NaN
# 3                         4.0  ...                             NaN
# 7                         3.0  ...                             NaN
# 31                        4.0  ...                             NaN
# 9                         3.0  ...                             NaN
# 16                        4.0  ...                             NaN
# 30                        5.0  ...                             NaN
# 14                        4.0  ...                             NaN
# 2                         4.0  ...                             NaN
# 1                         4.0  ...                             NaN
# 34                        NaN  ...                             NaN
# 25                        4.0  ...                             NaN
# 29                        4.0  ...                             NaN
# 20                        NaN  ...                             NaN
# 8                         4.0  ...                             NaN
# 22                        3.0  ...                             NaN
# 27                        5.0  ...                             NaN
# 11                        4.0  ...                             NaN
# 10                        3.0  ...                             NaN
# 18                        4.0  ...                             NaN
# 23                        4.0  ...                             NaN
# 26                        5.0  ...                             NaN
# 24                        2.0  ...                             NaN
# 13                        2.0  ...                             NaN
#
#     Alice in Wonderland (2010)  Argo (2012)  Gods Must Be Crazy, The (1980)  \
# 0                          NaN          NaN                             NaN
# 6                          NaN          NaN                             NaN
# 32                         NaN          NaN                             NaN
# 28                         NaN          NaN                             NaN
# 15                         NaN          NaN                             NaN
# 33                         NaN          NaN                             NaN
# 4                          NaN          NaN                             NaN
# 19                         NaN          NaN                             NaN
# 12                         NaN          NaN                             NaN
# 5                          NaN          NaN                             NaN
# 17                         NaN          NaN                             NaN
# 21                         NaN          NaN                             NaN
# 3                          NaN          NaN                             NaN
# 7                          NaN          NaN                             NaN
# 31                         NaN          NaN                             NaN
# 9                          NaN          NaN                             NaN
# 16                         NaN          NaN                             NaN
# 30                         NaN          NaN                             NaN
# 14                         NaN          NaN                             NaN
# 2                          NaN          NaN                             NaN
# 1                          NaN          NaN                             NaN
# 34                         NaN          NaN                             NaN
# 25                         NaN          NaN                             NaN
# 29                         NaN          NaN                             NaN
# 20                         NaN          NaN                             NaN
# 8                          NaN          NaN                             NaN
# 22                         NaN          NaN                             NaN
# 27                         NaN          NaN                             NaN
# 11                         NaN          NaN                             NaN
# 10                         NaN          NaN                             NaN
# 18                         NaN          NaN                             NaN
# 23                         NaN          NaN                             NaN
# 26                         NaN          NaN                             NaN
# 24                         NaN          NaN                             NaN
# 13                         NaN          NaN                             NaN
#
#     Step Brothers (2008)  Grand Day Out with Wallace and Gromit, A (1989)  \
# 0                    NaN                                              NaN
# 6                    NaN                                              NaN
# 32                   NaN                                              NaN
# 28                   NaN                                              NaN
# 15                   NaN                                              NaN
# 33                   NaN                                              NaN
# 4                    NaN                                              NaN
# 19                   NaN                                              NaN
# 12                   NaN                                              NaN
# 5                    NaN                                              NaN
# 17                   NaN                                              NaN
# 21                   NaN                                              NaN
# 3                    NaN                                              NaN
# 7                    NaN                                              NaN
# 31                   NaN                                              NaN
# 9                    NaN                                              NaN
# 16                   NaN                                              NaN
# 30                   NaN                                              NaN
# 14                   NaN                                              NaN
# 2                    NaN                                              NaN
# 1                    NaN                                              NaN
# 34                   NaN                                              NaN
# 25                   NaN                                              NaN
# 29                   NaN                                              NaN
# 20                   NaN                                              NaN
# 8                    NaN                                              NaN
# 22                   NaN                                              NaN
# 27                   NaN                                              NaN
# 11                   NaN                                              NaN
# 10                   NaN                                              NaN
# 18                   NaN                                              NaN
# 23                   NaN                                              NaN
# 26                   NaN                                              NaN
# 24                   NaN                                              NaN
# 13                   NaN                                              NaN
#
#     Inglourious Basterds (2009)  Back to the Future Part III (1990)  \
# 0                           NaN                                 NaN
# 6                           NaN                                 NaN
# 32                          NaN                                 NaN
# 28                          NaN                                 NaN
# 15                          NaN                                 NaN
# 33                          NaN                                 NaN
# 4                           NaN                                 NaN
# 19                          NaN                                 NaN
# 12                          NaN                                 NaN
# 5                           NaN                                 NaN
# 17                          NaN                                 NaN
# 21                          NaN                                 NaN
# 3                           NaN                                 NaN
# 7                           NaN                                 NaN
# 31                          NaN                                 NaN
# 9                           NaN                                 NaN
# 16                          NaN                                 NaN
# 30                          NaN                                 NaN
# 14                          NaN                                 NaN
# 2                           NaN                                 NaN
# 1                           NaN                                 NaN
# 34                          NaN                                 NaN
# 25                          NaN                                 NaN
# 29                          NaN                                 NaN
# 20                          NaN                                 NaN
# 8                           NaN                                 NaN
# 22                          NaN                                 NaN
# 27                          NaN                                 NaN
# 11                          NaN                                 NaN
# 10                          NaN                                 NaN
# 18                          NaN                                 NaN
# 23                          NaN                                 NaN
# 26                          NaN                                 NaN
# 24                          NaN                                 NaN
# 13                          NaN                                 NaN
#
#     Pay It Forward (2000)  Dracula (Bram Stoker's Dracula) (1992)
# 0                     NaN                                     NaN
# 6                     NaN                                     NaN
# 32                    NaN                                     NaN
# 28                    NaN                                     NaN
# 15                    NaN                                     NaN
# 33                    NaN                                     NaN
# 4                     NaN                                     NaN
# 19                    NaN                                     NaN
# 12                    NaN                                     NaN
# 5                     NaN                                     NaN
# 17                    NaN                                     NaN
# 21                    NaN                                     NaN
# 3                     NaN                                     NaN
# 7                     NaN                                     NaN
# 31                    NaN                                     NaN
# 9                     NaN                                     NaN
# 16                    NaN                                     NaN
# 30                    NaN                                     NaN
# 14                    NaN                                     NaN
# 2                     NaN                                     NaN
# 1                     NaN                                     NaN
# 34                    NaN                                     NaN
# 25                    NaN                                     NaN
# 29                    NaN                                     NaN
# 20                    NaN                                     NaN
# 8                     NaN                                     NaN
# 22                    NaN                                     NaN
# 27                    NaN                                     NaN
# 11                    NaN                                     NaN
# 10                    NaN                                     NaN
# 18                    NaN                                     NaN
# 23                    NaN                                     NaN
# 26                    NaN                                     NaN
# 24                    NaN                                     NaN
# 13                    NaN                                     NaN
#
# [35 rows x 300 columns]

# %%
# Predict for a specific user

# Pick a user ID from the dataset
user_id = 7
# Get all this user's ratings
user_2_ratings  = cluster.loc[user_id, :]
# Which movies did they not rate?
user_2_unrated_movies =  user_2_ratings[user_2_ratings.isnull()]
# What are the ratings of these movies the user did not rate?
avg_ratings = pd.concat([user_2_unrated_movies, cluster.mean()], axis=1, join='inner').loc[:,0]
# Let's sort by rating so the highest rated movies are presented first
avg_ratings.sort_values(ascending=False)[:20]
# Out:
# Terminator, The (1984)                                    5.000000
# Wallace & Gromit: The Best of Aardman Animation (1996)    5.000000
# Notting Hill (1999)                                       5.000000
# When Harry Met Sally... (1989)                            5.000000
# Star Wars: Episode IV - A New Hope (1977)                 5.000000
# Jerry Maguire (1996)                                      5.000000
# Lethal Weapon 3 (1992)                                    5.000000
# How to Lose a Guy in 10 Days (2003)                       5.000000
# Matrix, The (1999)                                        5.000000
# Bruce Almighty (2003)                                     5.000000
# Underworld (2003)                                         5.000000
# 2001: A Space Odyssey (1968)                              5.000000
# You've Got Mail (1998)                                    5.000000
# Spider-Man 2 (2004)                                       5.000000
# Miss Congeniality (2000)                                  5.000000
# Bodyguard, The (1992)                                     5.000000
# Men in Black (a.k.a. MIB) (1997)                          4.750000
# Wallace & Gromit: A Close Shave (1995)                    4.666667
# Shawshank Redemption, The (1994)                          4.576923
# Schindler's List (1993)                                   4.555556
# Name: 0, dtype: float64

# %% [markdown]
# ## Using Collaborative Filtering (With fast.ai)

# %%
! [ -e /content ] && pip install -Uqq fastai

# %%
from fastai.tabular.all import *
from fastai.collab import *

# %% [markdown]
# ### Training a model

# %% [markdown]
# For this, we will use the [Movielens 100k data dataset](https://grouplens.org/datasets/movielens/100k/). We can download it easily and decompress it with the following function:

# %%
path = untar_data(URLs.ML_100k)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='4931584' class='' max='4924029' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.15% [4931584/4924029 00:00&lt;00:00]
#     </div>

# %% [markdown]
# The main table is in `u.data`. Since it's not a proper csv, we have to specify a few things while opening it: the tab delimiter, the columns we want to keep and their names.

# %%
ratings = pd.read_csv(path/'u.data', delimiter='\t', header=None,
                      usecols=(0,1,2), names=['user','movie','rating'])
ratings.head()
# Out:
#    user  movie  rating
# 0   196    242       3
# 1   186    302       3
# 2    22    377       1
# 3   244     51       2
# 4   166    346       1

# %% [markdown]
# Movie ids are not ideal to look at things, so we load the corresponding movie id to the title that is in the table `u.item`:

# %%
movies = pd.read_csv(path/'u.item',  delimiter='|', encoding='latin-1',
                     usecols=(0,1), names=('movie','title'), header=None)
movies.head()
# Out:
#    movie              title
# 0      1   Toy Story (1995)
# 1      2   GoldenEye (1995)
# 2      3  Four Rooms (1995)
# 3      4  Get Shorty (1995)
# 4      5     Copycat (1995)

# %% [markdown]
# Next we merge it to our ratings table:

# %%
ratings = ratings.merge(movies)
ratings.head()
# Out:
#    user  movie  rating         title
# 0   196    242       3  Kolya (1996)
# 1    63    242       3  Kolya (1996)
# 2   226    242       5  Kolya (1996)
# 3   154    242       3  Kolya (1996)
# 4   306    242       5  Kolya (1996)

# %% [markdown]
# We can then build a `DataLoaders` object from this table. By default, it takes the first column for user, the second column for the item (here our movies) and the third column for the ratings. We need to change the value of `item_name` in our case, to use the titles instead of the ids:

# %%
dls = CollabDataLoaders.from_df(ratings, item_name='title', bs=64)

# %% [markdown]
# In all applications, when the data has been assembled in a `DataLoaders`, you can have a look at it with the `show_batch` method:

# %%
dls.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>user</th>
#       <th>title</th>
#       <th>rating</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>326</td>
#       <td>Streetcar Named Desire, A (1951)</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>248</td>
#       <td>Clockwork Orange, A (1971)</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>922</td>
#       <td>Bridges of Madison County, The (1995)</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>484</td>
#       <td>Monty Python and the Holy Grail (1974)</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>264</td>
#       <td>Ransom (1996)</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>622</td>
#       <td>Some Like It Hot (1959)</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>334</td>
#       <td>Faster Pussycat! Kill! Kill! (1965)</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>488</td>
#       <td>Alien (1979)</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>331</td>
#       <td>Raising Arizona (1987)</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>7</td>
#       <td>Blues Brothers, The (1980)</td>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# fastai can create and train a collaborative filtering model by using `collab_learner`:

# %%
learn = collab_learner(dls, n_factors=50, y_range=(0, 5.5))

# %% [markdown]
# It uses a simple dot product model with 50 latent factors. To train it using the 1cycle policy, we just run this command:

# %%
learn.fit_one_cycle(5, 5e-3, wd=0.1)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.924275</td>
#       <td>0.954030</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.882202</td>
#       <td>0.875369</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.745054</td>
#       <td>0.827108</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.582514</td>
#       <td>0.815845</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.498050</td>
#       <td>0.816860</td>
#       <td>00:08</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Here's [some benchmarks](https://www.librec.net/release/v1.3/example.html) on the same dataset for the popular Librec system for collaborative filtering. They show best results based on RMSE of 0.91 (scroll down to the 100k dataset), which corresponds to an MSE of `0.91**2 = 0.83`. So in less than a minute, we got pretty good results!

# %% [markdown]
# ### Interpretation

# %% [markdown]
# Let's analyze the results of our previous model. We will keep the 1000 most rated movies for this:

# %%
g = ratings.groupby('title')['rating'].count()
top_movies = g.sort_values(ascending=False).index.values[:1000]
top_movies[:10]
# Out:
# array(['Star Wars (1977)', 'Contact (1997)', 'Fargo (1996)',
#        'Return of the Jedi (1983)', 'Liar Liar (1997)',
#        'English Patient, The (1996)', 'Scream (1996)', 'Toy Story (1995)',
#        'Air Force One (1997)', 'Independence Day (ID4) (1996)'],
#       dtype=object)

# %% [markdown]
# ### Movie bias

# %% [markdown]
# Our model has learned one bias per movie, a unique number independent of users that can be interpreted as the intrinsic "value" of the movie. We can grab the bias of each movie in our `top_movies` list with the following command:

# %%
movie_bias = learn.model.bias(top_movies, is_item=True)
movie_bias.shape
# Out:
# torch.Size([1000])

# %% [markdown]
# Let's compare those biases with the average ratings:

# %%
mean_ratings = ratings.groupby('title')['rating'].mean()
movie_ratings = [(b, i, mean_ratings.loc[i]) for i,b in zip(top_movies,movie_bias)]

# %% [markdown]
# Now let's have a look at the movies with the worst bias:

# %%
item0 = lambda o:o[0]
sorted(movie_ratings, key=item0)[:15]
# Out:
# [(tensor(-0.3497),
#   'Children of the Corn: The Gathering (1996)',
#   1.3157894736842106),
#  (tensor(-0.2999),
#   'Lawnmower Man 2: Beyond Cyberspace (1996)',
#   1.7142857142857142),
#  (tensor(-0.2812), 'Free Willy 3: The Rescue (1997)', 1.7407407407407407),
#  (tensor(-0.2797), 'Island of Dr. Moreau, The (1996)', 2.1578947368421053),
#  (tensor(-0.2743), 'Crow: City of Angels, The (1996)', 1.9487179487179487),
#  (tensor(-0.2720), 'Cable Guy, The (1996)', 2.339622641509434),
#  (tensor(-0.2562), 'Barb Wire (1996)', 1.9333333333333333),
#  (tensor(-0.2469), 'Bio-Dome (1996)', 1.903225806451613),
#  (tensor(-0.2294), 'Leave It to Beaver (1997)', 1.8409090909090908),
#  (tensor(-0.2247), 'Keys to Tulsa (1997)', 2.24),
#  (tensor(-0.2096), "Stephen King's The Langoliers (1995)", 2.413793103448276),
#  (tensor(-0.2047), 'Spice World (1997)', 2.1153846153846154),
#  (tensor(-0.2013), 'Playing God (1997)', 2.627906976744186),
#  (tensor(-0.2007), 'Beverly Hills Ninja (1997)', 2.3125),
#  (tensor(-0.2004), 'Mortal Kombat: Annihilation (1997)', 1.9534883720930232)]

# %% [markdown]
# Or the ones with the best bias:

# %%
sorted(movie_ratings, key=lambda o: o[0], reverse=True)[:15]
# Out:
# [(tensor(0.5875), 'Shawshank Redemption, The (1994)', 4.445229681978798),
#  (tensor(0.5550), 'Titanic (1997)', 4.2457142857142856),
#  (tensor(0.5351), 'Silence of the Lambs, The (1991)', 4.28974358974359),
#  (tensor(0.5309), 'Good Will Hunting (1997)', 4.262626262626263),
#  (tensor(0.5156), 'L.A. Confidential (1997)', 4.161616161616162),
#  (tensor(0.5071), 'Star Wars (1977)', 4.3584905660377355),
#  (tensor(0.4917), 'Rear Window (1954)', 4.3875598086124405),
#  (tensor(0.4702), "Schindler's List (1993)", 4.466442953020135),
#  (tensor(0.4678), 'Wrong Trousers, The (1993)', 4.466101694915254),
#  (tensor(0.4587), 'Usual Suspects, The (1995)', 4.385767790262173),
#  (tensor(0.4551), 'To Kill a Mockingbird (1962)', 4.292237442922374),
#  (tensor(0.4521),
#   'Wallace & Gromit: The Best of Aardman Animation (1996)',
#   4.447761194029851),
#  (tensor(0.4446), 'As Good As It Gets (1997)', 4.196428571428571),
#  (tensor(0.4404), 'Boot, Das (1981)', 4.203980099502488),
#  (tensor(0.4400), 'Henry V (1989)', 4.137096774193548)]

# %% [markdown]
# There is certainly a strong correlation!

# %% [markdown]
# ### Movie weights

# %% [markdown]
# Now let's try to analyze the latent factors our model has learned. We can grab the weights for each movie in `top_movies` the same way as we did for the bias before.

# %%
movie_w = learn.model.weight(top_movies, is_item=True)
movie_w.shape
# Out:
# torch.Size([1000, 50])

# %% [markdown]
# Let's try a PCA to reduce the dimensions and see if we can see what the model learned:

# %%
movie_pca = movie_w.pca(3)
movie_pca.shape
# Out:
# torch.Size([1000, 3])

# %%
fac0,fac1,fac2 = movie_pca.t()
movie_comp = [(f, i) for f,i in zip(fac0, top_movies)]

# %% [markdown]
# Here are the highest score on the first dimension:

# %%
sorted(movie_comp, key=itemgetter(0), reverse=True)[:10]
# Out:
# [(tensor(1.2053), 'Congo (1995)'),
#  (tensor(1.1595), 'Bio-Dome (1996)'),
#  (tensor(1.1528), 'Home Alone 3 (1997)'),
#  (tensor(1.1450), 'D3: The Mighty Ducks (1996)'),
#  (tensor(1.1165), 'Leave It to Beaver (1997)'),
#  (tensor(1.1149), "McHale's Navy (1997)"),
#  (tensor(1.0975), 'Batman & Robin (1997)'),
#  (tensor(1.0957), 'Jungle2Jungle (1997)'),
#  (tensor(1.0776), 'Children of the Corn: The Gathering (1996)'),
#  (tensor(1.0562), 'Grease 2 (1982)')]

# %% [markdown]
# And the worst:

# %%
sorted(movie_comp, key=itemgetter(0))[:10]
# Out:
# [(tensor(-1.1758), 'Close Shave, A (1995)'),
#  (tensor(-1.1123), 'Casablanca (1942)'),
#  (tensor(-1.0824),
#   'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1963)'),
#  (tensor(-1.0060), 'Chinatown (1974)'),
#  (tensor(-0.9935), 'Godfather, The (1972)'),
#  (tensor(-0.9833), 'Third Man, The (1949)'),
#  (tensor(-0.9671), 'Wrong Trousers, The (1993)'),
#  (tensor(-0.9610), 'Eat Drink Man Woman (1994)'),
#  (tensor(-0.9512), 'North by Northwest (1959)'),
#  (tensor(-0.9465), '12 Angry Men (1957)')]

# %% [markdown]
# Same thing for our second dimension:

# %%
movie_comp = [(f, i) for f,i in zip(fac1, top_movies)]

# %%
sorted(movie_comp, key=itemgetter(0), reverse=True)[:10]
# Out:
# [(tensor(1.0052), 'Stupids, The (1996)'),
#  (tensor(0.8383), 'Jude (1996)'),
#  (tensor(0.8211), 'Serial Mom (1994)'),
#  (tensor(0.8091), 'Showgirls (1995)'),
#  (tensor(0.7721), 'Cable Guy, The (1996)'),
#  (tensor(0.7707), 'Pallbearer, The (1996)'),
#  (tensor(0.7683), 'Stuart Saves His Family (1995)'),
#  (tensor(0.7673), 'Road to Wellville, The (1994)'),
#  (tensor(0.7639), 'Lost Highway (1997)'),
#  (tensor(0.7610), 'Brazil (1985)')]

# %%
sorted(movie_comp, key=itemgetter(0))[:10]
# Out:
# [(tensor(-1.1628), 'Braveheart (1995)'),
#  (tensor(-1.1572), 'Raiders of the Lost Ark (1981)'),
#  (tensor(-1.0285), 'Titanic (1997)'),
#  (tensor(-0.9605), 'American President, The (1995)'),
#  (tensor(-0.8914), 'Independence Day (ID4) (1996)'),
#  (tensor(-0.8717), "It's a Wonderful Life (1946)"),
#  (tensor(-0.8662), 'Forrest Gump (1994)'),
#  (tensor(-0.8501), 'Indiana Jones and the Last Crusade (1989)'),
#  (tensor(-0.8450), 'True Lies (1994)'),
#  (tensor(-0.8443), 'Time to Kill, A (1996)')]

# %% [markdown]
# And we can even plot the movies according to their scores on those dimensions:

# %%
idxs = np.random.choice(len(top_movies), 50, replace=False)
idxs = list(range(50))
X = fac0[idxs]
Y = fac2[idxs]
plt.figure(figsize=(15,15))
plt.scatter(X, Y)
for i, x, y in zip(top_movies[idxs], X, Y):
    plt.text(x,y,i, color=np.random.rand(3)*0.7, fontsize=11)
plt.show()

# %% [markdown]
# # Exercise 2
#
# ## Play around with different collaborative filtering model parameters such as n_factors and other parameters.
# ## Identify if any such parameters have impact on the speed of convergence or the performance on the model

# %%
# !pip install scikit-surprise
from surprise import Dataset
from surprise.model_selection import cross_validate
from surprise.prediction_algorithms import SVD

#Load the dataset (you can replace 'ml-100k with any other dataset supported by Surprise)
data= Dataset.load_builtin('ml-100k')

#Define a parameter grid to experiment with
param_grid={'n_factors':[50,100,150],
            'reg_all':[0.01,0.02,0.03],
            'lr_all':[0.005,0.01,0.015],
            'n_epochs':[10,20,30]}

#Iterate over parameter combinations
for n_factors in param_grid['n_factors']:
    for reg_all in param_grid['reg_all']:
        for lr_all in param_grid['lr_all']:
            for n_epochs in param_grid['n_epochs']:
                 #Define the model with current parameters
                 model=SVD(n_factors=n_factors, reg_all=reg_all, lr_all=lr_all, n_epochs=n_epochs)

                 #Perform cross-validation
                 cv_results=cross_validate(model, data, measures=['RMSE'], cv=5, verbose=True)

                 #Extract and print the mean RMSE
                 mean_rmse=cv_results['test_rmse'].mean()
                 print(f"Parameters:n_factors={n_factors}, reg_all={reg_all}, lr_all={lr_all}, n_epochs={n_epochs}")
                 print(f"Mean RMSE:{mean_rmse}")
# Out:
# Collecting scikit-surprise
#   Downloading scikit-surprise-1.1.3.tar.gz (771 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 772.0/772.0 kB 10.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: joblib>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.3.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.25.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.11.4)
# Building wheels for collected packages: scikit-surprise
#   Building wheel for scikit-surprise (setup.py) ... done
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.3-cp310-cp310-linux_x86_64.whl size=3163008 sha256=5f813cd17987a93e9e53a8221164ee633f919f1b3667e6ca7ffc2de56341263f
#   Stored in directory: /root/.cache/pip/wheels/a5/ca/a8/4e28def53797fdc4363ca4af740db15a9c2f1595ebc51fb445
# Successfully built scikit-surprise
# Installing collected packages: scikit-surprise
# Successfully installed scikit-surprise-1.1.3
# Dataset ml-100k could not be found. Do you want to download it? [Y/n] Y
# Trying to download dataset from https://files.grouplens.org/datasets/movielens/ml-100k.zip...
# Done! Dataset ml-100k has been saved to /root/.surprise_data/ml-100k
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9521  0.9404  0.9472  0.9395  0.9551  0.9469  0.0062
# Fit time          0.33    0.34    0.33    0.34    0.34    0.33    0.01
# Test time         0.21    0.31    0.11    0.11    0.10    0.17    0.08
# Parameters:n_factors=50, reg_all=0.01, lr_all=0.005, n_epochs=10
# Mean RMSE:0.9468525505561759
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9446  0.9387  0.9394  0.9285  0.9391  0.9381  0.0052
# Fit time          0.69    0.65    0.66    0.63    0.60    0.65    0.03
# Test time         0.10    0.28    0.09    0.10    0.11    0.14    0.07
# Parameters:n_factors=50, reg_all=0.01, lr_all=0.005, n_epochs=20
# Mean RMSE:0.9380712497403358
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9487  0.9459  0.9520  0.9548  0.9560  0.9515  0.0038
# Fit time          0.90    1.10    1.45    0.89    0.89    1.04    0.22
# Test time         0.11    0.17    0.18    0.11    0.11    0.14    0.03
# Parameters:n_factors=50, reg_all=0.01, lr_all=0.005, n_epochs=30
# Mean RMSE:0.9514740631749532
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9419  0.9354  0.9329  0.9347  0.9427  0.9375  0.0040
# Fit time          0.34    0.36    0.34    0.35    0.35    0.35    0.00
# Test time         0.33    0.11    0.12    0.11    0.10    0.15    0.09
# Parameters:n_factors=50, reg_all=0.01, lr_all=0.01, n_epochs=10
# Mean RMSE:0.9375053058298185
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9803  0.9676  0.9707  0.9759  0.9844  0.9758  0.0061
# Fit time          0.61    0.62    0.64    0.62    0.82    0.66    0.08
# Test time         0.28    0.10    0.10    0.18    0.17    0.17    0.06
# Parameters:n_factors=50, reg_all=0.01, lr_all=0.01, n_epochs=20
# Mean RMSE:0.9757832608273166
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0115  1.0195  1.0114  1.0210  1.0186  1.0164  0.0041
# Fit time          1.43    0.90    0.91    0.98    0.93    1.03    0.20
# Test time         0.31    0.11    0.11    0.11    0.12    0.15    0.08
# Parameters:n_factors=50, reg_all=0.01, lr_all=0.01, n_epochs=30
# Mean RMSE:1.0163851770753949
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9520  0.9545  0.9457  0.9476  0.9549  0.9509  0.0037
# Fit time          0.35    0.34    0.34    0.34    0.35    0.34    0.01
# Test time         0.29    0.11    0.11    0.10    0.10    0.14    0.07
# Parameters:n_factors=50, reg_all=0.01, lr_all=0.015, n_epochs=10
# Mean RMSE:0.9509333906730454
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0139  1.0171  1.0104  1.0258  1.0194  1.0173  0.0052
# Fit time          0.65    0.70    0.97    0.65    0.61    0.72    0.13
# Test time         0.33    0.17    0.17    0.12    0.11    0.18    0.08
# Parameters:n_factors=50, reg_all=0.01, lr_all=0.015, n_epochs=20
# Mean RMSE:1.017329516142277
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0491  1.0539  1.0499  1.0526  1.0440  1.0499  0.0034
# Fit time          0.90    0.95    0.93    0.87    0.94    0.92    0.03
# Test time         0.29    0.12    0.23    0.14    0.10    0.18    0.07
# Parameters:n_factors=50, reg_all=0.01, lr_all=0.015, n_epochs=30
# Mean RMSE:1.049892736282775
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9399  0.9497  0.9522  0.9439  0.9452  0.9462  0.0044
# Fit time          0.36    0.37    0.36    0.43    0.53    0.41    0.06
# Test time         0.11    0.10    0.10    0.17    0.17    0.13    0.04
# Parameters:n_factors=50, reg_all=0.02, lr_all=0.005, n_epochs=10
# Mean RMSE:0.946186922181832
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9381  0.9384  0.9253  0.9426  0.9261  0.9341  0.0070
# Fit time          0.82    0.61    0.65    0.62    0.62    0.66    0.08
# Test time         0.36    0.13    0.11    0.10    0.21    0.18    0.10
# Parameters:n_factors=50, reg_all=0.02, lr_all=0.005, n_epochs=20
# Mean RMSE:0.934089693536085
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9405  0.9363  0.9395  0.9383  0.9393  0.9388  0.0014
# Fit time          0.86    0.97    0.92    0.93    0.99    0.93    0.05
# Test time         0.29    0.11    0.10    0.10    0.17    0.15    0.07
# Parameters:n_factors=50, reg_all=0.02, lr_all=0.005, n_epochs=30
# Mean RMSE:0.9387790039719077
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9355  0.9393  0.9422  0.9314  0.9237  0.9344  0.0065
# Fit time          0.52    0.48    0.34    0.36    0.34    0.41    0.08
# Test time         0.40    0.11    0.12    0.11    0.11    0.17    0.12
# Parameters:n_factors=50, reg_all=0.02, lr_all=0.01, n_epochs=10
# Mean RMSE:0.9344250027662003
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9518  0.9499  0.9476  0.9466  0.9576  0.9507  0.0039
# Fit time          0.61    0.63    0.60    0.61    0.62    0.62    0.01
# Test time         0.36    0.10    0.11    0.10    0.10    0.15    0.10
# Parameters:n_factors=50, reg_all=0.02, lr_all=0.01, n_epochs=20
# Mean RMSE:0.9507075257983197
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9900  0.9818  0.9898  0.9769  0.9795  0.9836  0.0054
# Fit time          0.94    0.95    0.92    1.52    0.90    1.05    0.24
# Test time         0.28    0.10    0.16    0.14    0.18    0.17    0.06
# Parameters:n_factors=50, reg_all=0.02, lr_all=0.01, n_epochs=30
# Mean RMSE:0.9836257456683871
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9323  0.9393  0.9387  0.9315  0.9320  0.9347  0.0035
# Fit time          0.37    0.35    0.37    0.32    0.33    0.35    0.02
# Test time         0.31    0.11    0.10    0.10    0.14    0.15    0.08
# Parameters:n_factors=50, reg_all=0.02, lr_all=0.015, n_epochs=10
# Mean RMSE:0.9347482212841044
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9823  0.9731  0.9843  0.9845  0.9800  0.9808  0.0042
# Fit time          0.61    0.64    0.63    0.60    0.60    0.62    0.02
# Test time         0.28    0.10    0.11    0.18    0.11    0.15    0.07
# Parameters:n_factors=50, reg_all=0.02, lr_all=0.015, n_epochs=20
# Mean RMSE:0.9808246937684881
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0099  1.0156  1.0055  1.0083  1.0097  1.0098  0.0033
# Fit time          0.87    1.50    0.96    0.93    0.94    1.04    0.23
# Test time         0.41    0.19    0.11    0.11    0.12    0.19    0.11
# Parameters:n_factors=50, reg_all=0.02, lr_all=0.015, n_epochs=30
# Mean RMSE:1.0097846779648278
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9487  0.9434  0.9465  0.9428  0.9490  0.9461  0.0026
# Fit time          0.34    0.33    0.34    0.32    0.35    0.34    0.01
# Test time         0.30    0.15    0.10    0.22    0.16    0.19    0.07
# Parameters:n_factors=50, reg_all=0.03, lr_all=0.005, n_epochs=10
# Mean RMSE:0.9460811464531478
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9382  0.9258  0.9401  0.9329  0.9317  0.9338  0.0051
# Fit time          0.62    0.63    0.62    1.03    0.93    0.77    0.18
# Test time         0.33    0.10    0.10    0.17    0.10    0.16    0.09
# Parameters:n_factors=50, reg_all=0.03, lr_all=0.005, n_epochs=20
# Mean RMSE:0.9337575345039234
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9323  0.9258  0.9319  0.9240  0.9321  0.9292  0.0036
# Fit time          0.92    0.96    0.90    0.94    0.95    0.93    0.02
# Test time         0.29    0.11    0.15    0.11    0.11    0.15    0.07
# Parameters:n_factors=50, reg_all=0.03, lr_all=0.005, n_epochs=30
# Mean RMSE:0.9292139098394717
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9284  0.9335  0.9445  0.9333  0.9305  0.9340  0.0056
# Fit time          0.37    0.42    0.36    0.33    0.34    0.36    0.03
# Test time         0.29    0.12    0.11    0.10    0.11    0.15    0.07
# Parameters:n_factors=50, reg_all=0.03, lr_all=0.01, n_epochs=10
# Mean RMSE:0.9340203913884343
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9384  0.9360  0.9405  0.9286  0.9348  0.9357  0.0041
# Fit time          0.96    0.85    0.64    0.63    0.68    0.75    0.13
# Test time         0.39    0.11    0.10    0.10    0.10    0.16    0.11
# Parameters:n_factors=50, reg_all=0.03, lr_all=0.01, n_epochs=20
# Mean RMSE:0.9356584381928037
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9533  0.9542  0.9621  0.9571  0.9637  0.9581  0.0042
# Fit time          0.90    0.88    1.00    0.96    0.95    0.94    0.04
# Test time         0.27    0.10    0.12    0.23    0.10    0.17    0.07
# Parameters:n_factors=50, reg_all=0.03, lr_all=0.01, n_epochs=30
# Mean RMSE:0.9580560822915121
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9342  0.9316  0.9235  0.9236  0.9323  0.9290  0.0046
# Fit time          0.32    0.54    0.56    0.35    0.37    0.43    0.10
# Test time         0.10    0.17    0.18    0.10    0.33    0.18    0.08
# Parameters:n_factors=50, reg_all=0.03, lr_all=0.015, n_epochs=10
# Mean RMSE:0.9290224784782813
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9629  0.9534  0.9598  0.9680  0.9585  0.9605  0.0048
# Fit time          0.66    0.64    0.62    0.61    0.65    0.64    0.02
# Test time         0.11    0.12    0.21    0.10    0.34    0.17    0.09
# Parameters:n_factors=50, reg_all=0.03, lr_all=0.015, n_epochs=20
# Mean RMSE:0.9605047520288885
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9760  0.9736  0.9744  0.9825  0.9779  0.9769  0.0032
# Fit time          0.96    0.90    0.89    1.24    1.26    1.05    0.17
# Test time         0.10    0.12    0.10    0.17    0.37    0.17    0.10
# Parameters:n_factors=50, reg_all=0.03, lr_all=0.015, n_epochs=30
# Mean RMSE:0.9768796126228028
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9504  0.9453  0.9416  0.9525  0.9501  0.9480  0.0040
# Fit time          0.53    0.54    0.55    0.56    0.54    0.54    0.01
# Test time         0.11    0.12    0.11    0.10    0.37    0.16    0.10
# Parameters:n_factors=100, reg_all=0.01, lr_all=0.005, n_epochs=10
# Mean RMSE:0.9479923852091747
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9498  0.9513  0.9367  0.9521  0.9309  0.9441  0.0087
# Fit time          0.95    1.00    0.97    1.07    1.63    1.12    0.25
# Test time         0.10    0.11    0.11    0.36    0.13    0.16    0.10
# Parameters:n_factors=100, reg_all=0.01, lr_all=0.005, n_epochs=20
# Mean RMSE:0.9441483349098896
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9585  0.9556  0.9569  0.9571  0.9629  0.9582  0.0025
# Fit time          1.41    1.56    1.58    1.59    1.40    1.51    0.09
# Test time         0.10    0.20    0.11    0.31    0.10    0.16    0.08
# Parameters:n_factors=100, reg_all=0.01, lr_all=0.005, n_epochs=30
# Mean RMSE:0.9582003184659778
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9463  0.9301  0.9397  0.9527  0.9415  0.9421  0.0075
# Fit time          0.52    0.81    0.74    0.55    0.55    0.63    0.12
# Test time         0.12    0.17    0.10    0.12    0.33    0.17    0.08
# Parameters:n_factors=100, reg_all=0.01, lr_all=0.01, n_epochs=10
# Mean RMSE:0.9420688369893992
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9747  0.9762  0.9857  0.9747  0.9770  0.9777  0.0041
# Fit time          0.98    1.01    1.10    1.09    1.06    1.05    0.05
# Test time         0.12    0.10    0.10    0.10    0.37    0.16    0.11
# Parameters:n_factors=100, reg_all=0.01, lr_all=0.01, n_epochs=20
# Mean RMSE:0.9776523998609017
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0098  1.0013  0.9977  1.0085  0.9992  1.0033  0.0049
# Fit time          1.64    1.99    1.52    1.42    1.57    1.63    0.19
# Test time         0.17    0.11    0.11    0.10    0.30    0.16    0.08
# Parameters:n_factors=100, reg_all=0.01, lr_all=0.01, n_epochs=30
# Mean RMSE:1.003316285908954
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9606  0.9432  0.9558  0.9627  0.9562  0.9557  0.0068
# Fit time          0.55    0.55    0.57    0.57    0.78    0.60    0.09
# Test time         0.10    0.11    0.18    0.11    0.40    0.18    0.11
# Parameters:n_factors=100, reg_all=0.01, lr_all=0.015, n_epochs=10
# Mean RMSE:0.9557029318515886
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0080  0.9978  1.0020  1.0018  1.0074  1.0034  0.0038
# Fit time          1.32    1.04    1.04    1.04    1.05    1.10    0.11
# Test time         0.11    0.11    0.12    0.11    0.30    0.15    0.08
# Parameters:n_factors=100, reg_all=0.01, lr_all=0.015, n_epochs=20
# Mean RMSE:1.0034042456605148
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0189  1.0278  1.0215  1.0197  1.0144  1.0204  0.0044
# Fit time          1.56    1.59    2.18    1.53    1.52    1.67    0.26
# Test time         0.11    0.14    0.15    0.12    0.18    0.14    0.03
# Parameters:n_factors=100, reg_all=0.01, lr_all=0.015, n_epochs=30
# Mean RMSE:1.0204304638196178
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9489  0.9415  0.9474  0.9485  0.9536  0.9480  0.0039
# Fit time          0.54    0.52    0.55    0.54    0.56    0.54    0.01
# Test time         0.32    0.11    0.11    0.11    0.10    0.15    0.08
# Parameters:n_factors=100, reg_all=0.02, lr_all=0.005, n_epochs=10
# Mean RMSE:0.9479586456672173
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9351  0.9328  0.9409  0.9337  0.9382  0.9362  0.0030
# Fit time          1.04    1.32    1.33    0.95    1.08    1.14    0.16
# Test time         0.28    0.17    0.11    0.11    0.11    0.16    0.07
# Parameters:n_factors=100, reg_all=0.02, lr_all=0.005, n_epochs=20
# Mean RMSE:0.9361528848603499
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9408  0.9434  0.9452  0.9380  0.9407  0.9416  0.0025
# Fit time          2.31    1.53    1.49    2.15    1.49    1.79    0.36
# Test time         0.29    0.11    0.12    0.18    0.33    0.21    0.09
# Parameters:n_factors=100, reg_all=0.02, lr_all=0.005, n_epochs=30
# Mean RMSE:0.9416188270589526
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9404  0.9321  0.9408  0.9316  0.9357  0.9361  0.0039
# Fit time          0.55    0.54    0.55    0.60    0.56    0.56    0.02
# Test time         0.15    0.11    0.11    0.11    0.28    0.15    0.07
# Parameters:n_factors=100, reg_all=0.02, lr_all=0.01, n_epochs=10
# Mean RMSE:0.9361287254580171
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9532  0.9550  0.9590  0.9513  0.9594  0.9556  0.0032
# Fit time          1.04    1.02    0.98    1.60    1.09    1.15    0.23
# Test time         0.14    0.10    0.12    0.18    0.35    0.18    0.09
# Parameters:n_factors=100, reg_all=0.02, lr_all=0.01, n_epochs=20
# Mean RMSE:0.9555982390934687
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9796  0.9704  0.9736  0.9725  0.9627  0.9718  0.0055
# Fit time          1.41    1.55    1.53    1.51    1.60    1.52    0.06
# Test time         0.10    0.11    0.11    0.16    0.41    0.18    0.12
# Parameters:n_factors=100, reg_all=0.02, lr_all=0.01, n_epochs=30
# Mean RMSE:0.9717507700125732
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9406  0.9468  0.9461  0.9407  0.9409  0.9430  0.0028
# Fit time          0.75    0.58    0.55    0.56    0.53    0.59    0.08
# Test time         0.17    0.11    0.15    0.10    0.30    0.17    0.07
# Parameters:n_factors=100, reg_all=0.02, lr_all=0.015, n_epochs=10
# Mean RMSE:0.9430264491569946
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9721  0.9698  0.9674  0.9684  0.9724  0.9700  0.0020
# Fit time          1.01    0.98    1.01    1.04    1.01    1.01    0.02
# Test time         0.12    0.10    0.10    0.12    0.29    0.14    0.07
# Parameters:n_factors=100, reg_all=0.02, lr_all=0.015, n_epochs=20
# Mean RMSE:0.9700015719979345
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9885  0.9780  0.9754  0.9791  0.9674  0.9777  0.0068
# Fit time          2.25    1.52    1.59    1.56    1.42    1.67    0.30
# Test time         0.18    0.11    0.11    0.10    0.12    0.12    0.03
# Parameters:n_factors=100, reg_all=0.02, lr_all=0.015, n_epochs=30
# Mean RMSE:0.9776931433013173
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9517  0.9450  0.9473  0.9483  0.9411  0.9467  0.0035
# Fit time          0.53    0.56    0.54    0.82    0.78    0.65    0.13
# Test time         0.19    0.11    0.11    0.43    0.11    0.19    0.13
# Parameters:n_factors=100, reg_all=0.03, lr_all=0.005, n_epochs=10
# Mean RMSE:0.9466795219533953
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9385  0.9301  0.9321  0.9260  0.9392  0.9332  0.0050
# Fit time          0.99    1.05    1.13    1.03    1.05    1.05    0.04
# Test time         0.11    0.10    0.11    0.29    0.16    0.15    0.07
# Parameters:n_factors=100, reg_all=0.03, lr_all=0.005, n_epochs=20
# Mean RMSE:0.9331952714515287
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9297  0.9316  0.9379  0.9336  0.9327  0.9331  0.0027
# Fit time          1.35    1.58    1.87    1.38    1.47    1.53    0.19
# Test time         0.11    0.16    0.11    0.30    0.21    0.18    0.07
# Parameters:n_factors=100, reg_all=0.03, lr_all=0.005, n_epochs=30
# Mean RMSE:0.9330848492364618
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9397  0.9332  0.9290  0.9419  0.9213  0.9330  0.0074
# Fit time          0.48    0.49    0.49    0.51    0.52    0.50    0.02
# Test time         0.11    0.10    0.10    0.29    0.21    0.16    0.08
# Parameters:n_factors=100, reg_all=0.03, lr_all=0.01, n_epochs=10
# Mean RMSE:0.9330208865114665
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9301  0.9369  0.9319  0.9358  0.9421  0.9354  0.0042
# Fit time          0.96    1.37    1.21    0.93    0.97    1.09    0.17
# Test time         0.10    0.18    0.10    0.10    0.19    0.13    0.04
# Parameters:n_factors=100, reg_all=0.03, lr_all=0.01, n_epochs=20
# Mean RMSE:0.9353515975343857
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9493  0.9490  0.9499  0.9473  0.9434  0.9478  0.0024
# Fit time          1.40    1.47    1.57    1.61    1.91    1.59    0.18
# Test time         0.18    0.11    0.11    0.41    0.21    0.20    0.11
# Parameters:n_factors=100, reg_all=0.03, lr_all=0.01, n_epochs=30
# Mean RMSE:0.9477741494489624
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9292  0.9315  0.9325  0.9324  0.9270  0.9305  0.0021
# Fit time          0.50    0.51    0.51    0.52    0.51    0.51    0.01
# Test time         0.11    0.11    0.11    0.11    0.33    0.16    0.09
# Parameters:n_factors=100, reg_all=0.03, lr_all=0.015, n_epochs=10
# Mean RMSE:0.9304975159680557
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9534  0.9529  0.9493  0.9427  0.9495  0.9496  0.0038
# Fit time          0.94    0.98    0.92    0.94    1.42    1.04    0.19
# Test time         0.10    0.12    0.10    0.10    0.41    0.17    0.12
# Parameters:n_factors=100, reg_all=0.03, lr_all=0.015, n_epochs=20
# Mean RMSE:0.9495557692123414
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9594  0.9542  0.9523  0.9543  0.9559  0.9552  0.0024
# Fit time          1.45    1.45    1.38    1.38    1.43    1.42    0.03
# Test time         0.10    0.11    0.12    0.11    0.30    0.15    0.08
# Parameters:n_factors=100, reg_all=0.03, lr_all=0.015, n_epochs=30
# Mean RMSE:0.9551957264155376
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9551  0.9448  0.9542  0.9515  0.9466  0.9505  0.0041
# Fit time          0.66    0.67    1.07    0.88    0.69    0.79    0.16
# Test time         0.11    0.11    0.17    0.11    0.30    0.16    0.07
# Parameters:n_factors=150, reg_all=0.01, lr_all=0.005, n_epochs=10
# Mean RMSE:0.9504553925814483
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9432  0.9451  0.9483  0.9464  0.9494  0.9465  0.0022
# Fit time          1.34    1.30    1.26    1.28    1.27    1.29    0.03
# Test time         0.11    0.11    0.11    0.16    0.11    0.12    0.02
# Parameters:n_factors=150, reg_all=0.01, lr_all=0.005, n_epochs=20
# Mean RMSE:0.9464851009425856
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9658  0.9597  0.9605  0.9588  0.9659  0.9622  0.0031
# Fit time          2.58    1.94    1.84    1.84    1.84    2.01    0.29
# Test time         0.30    0.10    0.13    0.17    0.19    0.18    0.07
# Parameters:n_factors=150, reg_all=0.01, lr_all=0.005, n_epochs=30
# Mean RMSE:0.9621590762630448
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9447  0.9494  0.9435  0.9502  0.9483  0.9472  0.0026
# Fit time          0.69    1.05    0.84    0.66    0.67    0.78    0.15
# Test time         0.35    0.17    0.17    0.21    0.11    0.20    0.08
# Parameters:n_factors=150, reg_all=0.01, lr_all=0.01, n_epochs=10
# Mean RMSE:0.947226518476685
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9762  0.9751  0.9748  0.9807  0.9684  0.9750  0.0039
# Fit time          1.22    1.25    1.23    1.28    1.29    1.25    0.03
# Test time         0.29    0.10    0.11    0.11    0.16    0.15    0.07
# Parameters:n_factors=150, reg_all=0.01, lr_all=0.01, n_epochs=20
# Mean RMSE:0.9750474028493723
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9869  0.9867  0.9824  0.9941  0.9865  0.9873  0.0038
# Fit time          2.50    1.86    1.80    1.81    1.84    1.96    0.27
# Test time         0.28    0.12    0.10    0.10    0.10    0.14    0.07
# Parameters:n_factors=150, reg_all=0.01, lr_all=0.01, n_epochs=30
# Mean RMSE:0.9872894469540745
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9608  0.9544  0.9653  0.9632  0.9545  0.9596  0.0045
# Fit time          0.76    1.03    0.68    0.67    0.64    0.75    0.14
# Test time         0.41    0.18    0.11    0.11    0.12    0.18    0.12
# Parameters:n_factors=150, reg_all=0.01, lr_all=0.015, n_epochs=10
# Mean RMSE:0.9596471071478485
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9844  0.9845  0.9894  0.9799  0.9888  0.9854  0.0035
# Fit time          1.20    1.25    1.22    1.23    1.37    1.25    0.06
# Test time         0.28    0.10    0.10    0.12    0.17    0.15    0.07
# Parameters:n_factors=150, reg_all=0.01, lr_all=0.015, n_epochs=20
# Mean RMSE:0.9853943708606858
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9833  0.9945  0.9882  0.9876  0.9977  0.9903  0.0051
# Fit time          2.46    1.91    1.93    1.85    1.95    2.02    0.22
# Test time         0.36    0.11    0.11    0.10    0.34    0.21    0.12
# Parameters:n_factors=150, reg_all=0.01, lr_all=0.015, n_epochs=30
# Mean RMSE:0.9902639534256436
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9417  0.9574  0.9472  0.9473  0.9453  0.9477  0.0052
# Fit time          1.03    0.78    0.67    0.64    0.66    0.75    0.14
# Test time         0.18    0.10    0.11    0.11    0.34    0.17    0.09
# Parameters:n_factors=150, reg_all=0.02, lr_all=0.005, n_epochs=10
# Mean RMSE:0.9477465020987307
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9354  0.9531  0.9367  0.9355  0.9381  0.9398  0.0067
# Fit time          1.26    1.29    1.24    1.28    1.80    1.37    0.21
# Test time         0.11    0.10    0.15    0.12    0.42    0.18    0.12
# Parameters:n_factors=150, reg_all=0.02, lr_all=0.005, n_epochs=20
# Mean RMSE:0.9397733785719045
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9422  0.9475  0.9487  0.9454  0.9366  0.9441  0.0044
# Fit time          1.87    1.83    1.85    1.88    2.19    1.92    0.13
# Test time         0.11    0.11    0.19    0.12    0.42    0.19    0.12
# Parameters:n_factors=150, reg_all=0.02, lr_all=0.005, n_epochs=30
# Mean RMSE:0.9440838498396975
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9408  0.9358  0.9415  0.9411  0.9331  0.9384  0.0034
# Fit time          0.90    0.67    0.65    0.69    0.65    0.71    0.10
# Test time         0.12    0.12    0.11    0.14    0.36    0.17    0.10
# Parameters:n_factors=150, reg_all=0.02, lr_all=0.01, n_epochs=10
# Mean RMSE:0.938444018824639
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9432  0.9527  0.9510  0.9522  0.9571  0.9513  0.0045
# Fit time          1.28    1.27    1.32    1.49    1.71    1.41    0.17
# Test time         0.11    0.11    0.14    0.18    0.30    0.17    0.07
# Parameters:n_factors=150, reg_all=0.02, lr_all=0.01, n_epochs=20
# Mean RMSE:0.951250712466645
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9579  0.9586  0.9631  0.9617  0.9627  0.9608  0.0021
# Fit time          1.97    1.86    1.83    1.91    2.87    2.09    0.40
# Test time         0.14    0.11    0.15    0.11    0.41    0.18    0.12
# Parameters:n_factors=150, reg_all=0.02, lr_all=0.01, n_epochs=30
# Mean RMSE:0.9608100872633765
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9426  0.9439  0.9460  0.9466  0.9502  0.9459  0.0026
# Fit time          1.02    0.66    0.65    0.68    0.68    0.74    0.14
# Test time         0.13    0.12    0.11    0.12    0.30    0.15    0.07
# Parameters:n_factors=150, reg_all=0.02, lr_all=0.015, n_epochs=10
# Mean RMSE:0.9458601166559429
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9539  0.9563  0.9564  0.9610  0.9639  0.9583  0.0036
# Fit time          1.34    1.27    1.45    1.71    1.24    1.40    0.17
# Test time         0.11    0.12    0.17    0.14    0.30    0.17    0.07
# Parameters:n_factors=150, reg_all=0.02, lr_all=0.015, n_epochs=20
# Mean RMSE:0.9583046437281139
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9615  0.9539  0.9642  0.9664  0.9572  0.9606  0.0046
# Fit time          1.87    1.94    1.94    2.32    2.00    2.01    0.16
# Test time         0.12    0.13    0.12    0.19    0.29    0.17    0.06
# Parameters:n_factors=150, reg_all=0.02, lr_all=0.015, n_epochs=30
# Mean RMSE:0.9606400725088754
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9383  0.9516  0.9535  0.9535  0.9417  0.9477  0.0064
# Fit time          0.70    0.65    0.65    0.64    0.67    0.66    0.02
# Test time         0.10    0.10    0.11    0.12    0.31    0.15    0.08
# Parameters:n_factors=150, reg_all=0.03, lr_all=0.005, n_epochs=10
# Mean RMSE:0.9477059236260766
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9262  0.9325  0.9399  0.9321  0.9320  0.9325  0.0044
# Fit time          1.34    1.29    1.99    1.22    1.22    1.41    0.29
# Test time         0.14    0.10    0.18    0.12    0.29    0.17    0.07
# Parameters:n_factors=150, reg_all=0.03, lr_all=0.005, n_epochs=20
# Mean RMSE:0.9325296418883449
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9336  0.9395  0.9313  0.9274  0.9351  0.9334  0.0040
# Fit time          1.79    1.92    1.91    2.67    1.80    2.02    0.33
# Test time         0.11    0.13    0.10    0.12    0.30    0.15    0.08
# Parameters:n_factors=150, reg_all=0.03, lr_all=0.005, n_epochs=30
# Mean RMSE:0.9333749324443371
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9309  0.9368  0.9325  0.9283  0.9316  0.9320  0.0028
# Fit time          0.66    0.65    0.65    0.68    0.67    0.66    0.01
# Test time         0.10    0.14    0.18    0.14    0.30    0.17    0.07
# Parameters:n_factors=150, reg_all=0.03, lr_all=0.01, n_epochs=10
# Mean RMSE:0.932007314143293
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9423  0.9423  0.9360  0.9372  0.9334  0.9382  0.0035
# Fit time          1.31    1.44    1.79    1.28    1.24    1.41    0.20
# Test time         0.12    0.17    0.11    0.19    0.30    0.18    0.07
# Parameters:n_factors=150, reg_all=0.03, lr_all=0.01, n_epochs=20
# Mean RMSE:0.938235168717872
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9401  0.9414  0.9428  0.9386  0.9409  0.9408  0.0014
# Fit time          1.94    1.88    2.07    2.27    1.79    1.99    0.17
# Test time         0.12    0.16    0.17    0.12    0.32    0.18    0.07
# Parameters:n_factors=150, reg_all=0.03, lr_all=0.01, n_epochs=30
# Mean RMSE:0.9407508181373775
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9352  0.9303  0.9340  0.9330  0.9344  0.9334  0.0017
# Fit time          0.66    0.65    0.66    0.68    0.67    0.66    0.01
# Test time         0.12    0.19    0.12    0.10    0.33    0.17    0.08
# Parameters:n_factors=150, reg_all=0.03, lr_all=0.015, n_epochs=10
# Mean RMSE:0.933368498451389
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9423  0.9442  0.9441  0.9353  0.9490  0.9430  0.0044
# Fit time          1.30    1.92    1.22    1.26    1.28    1.40    0.26
# Test time         0.11    0.17    0.11    0.13    0.29    0.16    0.07
# Parameters:n_factors=150, reg_all=0.03, lr_all=0.015, n_epochs=20
# Mean RMSE:0.9429867841162448
# Evaluating RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9442  0.9413  0.9504  0.9399  0.9395  0.9431  0.0040
# Fit time          1.95    1.89    2.38    1.98    1.81    2.00    0.20
# Test time         0.13    0.11    0.18    0.16    0.28    0.17    0.06
# Parameters:n_factors=150, reg_all=0.03, lr_all=0.015, n_epochs=30
# Mean RMSE:0.9430646999651472
